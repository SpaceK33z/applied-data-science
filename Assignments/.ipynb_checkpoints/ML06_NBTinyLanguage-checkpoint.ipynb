# %% [markdown]
# ## Who's text is this?

# %% [markdown]
# This notebook contains a simple classifier to predict the author of a text (string) of words in a restricted language. An accompanying Excel file exists to generate instances of texts, labeled by an author. The generator instantiates preboiled instances in that the probability for using a word by a particular author is taken into account. As such the generator is at the same time a corpus generator and a means to check if the calculated classifier makes sense.

# %% [markdown]
# First, import the text corpus and create a sentence list and its label list.

# %%
import csv

f = open("ML06_Corpus1.csv")
corpus = [ row for row in csv.reader(f, delimiter=';')]
X = [" ".join(lst[1:]).strip(" ") for lst in corpus]
y = [lst[0] for lst in corpus]
print(corpus[:2])
print(X[:2])
print(y[:2])
# Out:
# [['Gerrit', 'soccer', 'soccer', 'car', 'difficult', 'difficult', 'soccer', 'difficult', 'soccer', 'car', 'difficult', 'car', '', '', '', ''], ['Gerrit', 'soccer', 'boring', 'car', 'boring', 'contract', 'boring', 'difficult', 'soccer', 'car', 'soccer', 'contract', 'boring', 'car', 'energy', 'soccer']]
# ['soccer soccer car difficult difficult soccer difficult soccer car difficult car', 'soccer boring car boring contract boring difficult soccer car soccer contract boring car energy soccer']
# ['Gerrit', 'Gerrit']

# %% [markdown]
# Suppose, you don't know anything about machine learning. Waht would be an approach to determine the author of a sentence, having this set of labeled sentences?

# %%
from collections import Counter

words_G = [word for row in corpus[:50] for word in row if word != '']
words_T = [word for row in corpus[50:] for word in row if word != '']
counts_G = Counter(words_G)
counts_T = Counter(words_T)
total_G = sum(counts_G.values())
total_T = sum(counts_G.values())
perc_G = {key: value/total_G for  (key, value) in counts_G.items()}
perc_T = {key: value/total_T for  (key, value) in counts_T.items()}

print(perc_G)
print(perc_T)
# Out:
# {'Gerrit': 0.09615384615384616, 'difficult': 0.1076923076923077, 'boring': 0.06923076923076923, 'contract': 0.13076923076923078, 'energy': 0.028846153846153848, 'soccer': 0.2153846153846154, 'car': 0.19615384615384615, 'sweet': 0.15576923076923077}
# {'Truus': 0.09615384615384616, 'boring': 0.3038461538461538, 'sweet': 0.05576923076923077, 'contract': 0.08461538461538462, 'energy': 0.2673076923076923, 'difficult': 0.04423076923076923, 'car': 0.12115384615384615, 'soccer': 0.07692307692307693}

# %%
def determine_author(sentence, perc1, perc2):
    prod1 = prod2 = 1.0
    for word in sentence:
        prod1 *= perc1[word]
        prod2 *= perc2[word]
        # print(prod1, prod2)
    return prod1 > prod2

# determine_author(X[1].split(" "), perc_G, perc_T)

for sentence in X[:50]:
    print(determine_author(sentence.split(" "), perc_G, perc_T), end=';')

print("\n=====")

for sentence in X[50:]:
    print(determine_author(sentence.split(" "), perc_G, perc_T), end=';')
# Out:
# True;False;True;True;True;True;True;True;True;True;True;True;True;True;True;True;True;True;True;True;False;True;True;True;True;True;True;False;True;True;True;True;True;True;True;True;True;True;True;True;True;True;True;True;True;True;True;True;True;True;
# =====
# False;False;False;False;False;False;False;False;False;False;False;False;False;False;False;False;False;False;False;False;False;False;False;False;False;True;False;False;False;False;False;False;False;False;False;False;False;False;False;False;False;False;False;False;False;False;False;False;False;False;

# %% [markdown]
# Well, that's interesting and perhaps a bit embarassing at the same time. I would have expected the first set of 50 all True (author = 'Gerrit' and the subsequent 50 all False. But in both sets some unexpected negates slip through. The only explanation I can think of right now is that the generator has generated a string, attributed to Gerrit that is more likely to have been written by Truus. This could be true due to the randimization in the generation.
#
# _Question_: can you think of a better explanation?

# %% [markdown]
# Next, we are defining the evaluate_cross_validation() function as we did in previous notebooks. As it seems that we are using this function in many notebooks, it would be a good idea to put it (together with other goodies) in a module. For now, we just repeat ourselves.

# %%
from sklearn.cross_validation import cross_val_score, KFold
from numpy import mean
from scipy.stats import sem

def evaluate_cross_validation(clf, X, y, K):
    # create a k-fold cross validation iterator of k=5 folds
    cv = KFold(len(y), K, shuffle=True, random_state=0)
    # by default the score used is the one returned by score method of the estimator (accuracy)
    scores = cross_val_score(clf, X, y, cv=cv)
    print(scores)
    print("Mean score: {0:.3f}".format(mean(scores)))
    print("Standard error of the mean: (+/-{0:.3f})".format(sem(scores)))

# %% [markdown]
# Note that we create our validation folds from our complete dataset as contrasted to creating folds from the training set in the SVM notebook...
#
# What's that vectorizer thing doin in our classifier? Well, our Naive Bayes classifier can only deal with numeric data. So we have to map the texts to numeric data. That's in short what the vectorizer does: it creates a vector of features that we can give numeric values. The CountVectorizer is one of the simplest vectorizers available: it just creates a feature for each unique word in the text an then counts occurrences of each word in a text.
# There are also other vectorizers available in sklearn, such as the HashingVectorizer. Using the HashingVectorizer leads to a smaller feature space as different unique words may be hashed to the same bucket. The buckets form the feature space. Also, vectorizers may have paramaters. See the sklearn docs for which params you can use.

# %%
from sklearn.feature_extraction.text import CountVectorizer

vec = CountVectorizer()
print(X[:2])
print(vec.get_feature_names())
print(vec.fit_transform(X).toarray()[:2])
# Out:
# ['soccer soccer car difficult difficult soccer difficult soccer car difficult car', 'soccer boring car boring contract boring difficult soccer car soccer contract boring car energy soccer']
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# <ipython-input-6-64681bd2b580> in <module>()
#       3 vec = CountVectorizer()
#       4 print(X[:2])
# ----> 5 print(vec.get_feature_names())
#       6 print(vec.fit_transform(X).toarray()[:2])
#
# /Users/kees/anaconda/lib/python3.4/site-packages/sklearn/feature_extraction/text.py in get_feature_names(self)
#     888     def get_feature_names(self):
#     889         """Array mapping from feature integer indices to feature name"""
# --> 890         self._check_vocabulary()
#     891
#     892         return [t for t, i in sorted(six.iteritems(self.vocabulary_),
#
# /Users/kees/anaconda/lib/python3.4/site-packages/sklearn/feature_extraction/text.py in _check_vocabulary(self)
#     269         """Check if vocabulary is empty or missing (not fit-ed)"""
#     270         msg = "%(name)s - Vocabulary wasn't fitted."
# --> 271         check_is_fitted(self, 'vocabulary_', msg=msg),
#     272
#     273         if len(self.vocabulary_) == 0:
#
# /Users/kees/anaconda/lib/python3.4/site-packages/sklearn/utils/validation.py in check_is_fitted(estimator, attributes, msg, all_or_any)
#     625
#     626     if not all_or_any([hasattr(estimator, attr) for attr in attributes]):
# --> 627         raise NotFittedError(msg % {'name': type(estimator).__name__})
#
# NotFittedError: CountVectorizer - Vocabulary wasn't fitted.

# %% [markdown]
# Now, what do you think the output from the vectorizer means? Hint: the sum of each array is equal to the number of words in each sentence with the same index.

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import CountVectorizer

clf = Pipeline([('vect', CountVectorizer()), ('clf', MultinomialNB())])

evaluate_cross_validation(clf, X, y, 5)

# %% [markdown]
# Wew, that's pretty accurate. Ofcourse, that's especially because we've carefully crafted our dataset and took care to create users (Gerrit and Truus) that have really different writing styles. As an exercise you should create users with less distinct writing styles. You would probably see a smaller accuracy.

# %%
from sklearn.cross_validation import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=33)
print(X_train[:2])
print(y_train[:2])

# %%
from sklearn import metrics

def train_and_evaluate(clf, X_train, X_test, y_train, y_test):
    
    clf.fit(X_train, y_train)
    
    print("Accuracy on training set:")
    print(clf.score(X_train, y_train))
    print("Accuracy on testing set:")
    print(clf.score(X_test, y_test))
    
    y_pred = clf.predict(X_test)
    
    print("Classification Report:")
    print(metrics.classification_report(y_test, y_pred))
    print("Confusion Matrix:")
    print(metrics.confusion_matrix(y_test, y_pred))

# %% [markdown]
# Now, lets fit our modelfrom the train set and test it against the test set. Explain why our test set contains 25 measurements.

# %%
train_and_evaluate(clf, X_train, X_test, y_train, y_test)

# %% [markdown]
# We already tested the sentence below in our Excel sheet and it calculated Truus as an author. Sure enough our classifier also predicts Truus as the original author.

# %%
clf.predict(["contract energy contract sweet contract soccer contract energy difficult energy"])

# %% [markdown]
# __Assignment__: Now it's your turn to create a sentence generator for a small language (say, consisting of 10 words). You may get inspiration from the Excel generator, but of course you will use Python to create the generator. Generate a dataset (or: corpus) of 100 sentences attributed evenly to 2 authors. Your generator should take into account word preference of an author. Show that the more distinct preferences are, the more accurate your classifier is. And vice versa, the less distinct word preference is, the less accurate your classifier will be.
#
# This is quite a challenging assignment, but being almost halfway the course, we think you should be able to succeed.

# %%
import itertools
import random
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import Pipeline
from collections import Counter

authors = [
    ('Henk-Jan', [('yes', 30), ('like', 5), ('about', 40), ('again', 20), ('but', 10), ('because', 20), ('nice', 10)]),
    ('Geert', [('yes', 10), ('like', 20), ('about', 20), ('again', 5), ('but', 30), ('because', 2), ('nice', 50)])
]

parsed_authors = []

for a in authors:
    new = []
    for (word, count) in a[1]:
        x = [word] * count
        new.append(x)
    parsed_authors.append((a[0], list(itertools.chain(*new))))

# Show a list of all the words each author has said.
parsed_authors
# Out:
# [('Henk-Jan',
#   ['yes',
#    'yes',
#    'yes',
#    'yes',
#    'yes',
#    'yes',
#    'yes',
#    'yes',
#    'yes',
#    'yes',
#    'yes',
#    'yes',
#    'yes',
#    'yes',
#    'yes',
#    'yes',
#    'yes',
#    'yes',
#    'yes',
#    'yes',
#    'yes',
#    'yes',
#    'yes',
#    'yes',
#    'yes',
#    'yes',
#    'yes',
#    'yes',
#    'yes',
#    'yes',
#    'like',
#    'like',
#    'like',
#    'like',
#    'like',
#    'about',
#    'about',
#    'about',
#    'about',
#    'about',
#    'about',
#    'about',
#    'about',
#    'about',
#    'about',
#    'about',
#    'about',
#    'about',
#    'about',
#    'about',
#    'about',
#    'about',
#    'about',
#    'about',
#    'about',
#    'about',
#    'about',
#    'about',
#    'about',
#    'about',
#    'about',
#    'about',
#    'about',
#    'about',
#    'about',
#    'about',
#    'about',
#    'about',
#    'about',
#    'about',
#    'about',
#    'about',
#    'about',
#    'about',
#    'about',
#    'again',
#    'again',
#    'again',
#    'again',
#    'again',
#    'again',
#    'again',
#    'again',
#    'again',
#    'again',
#    'again',
#    'again',
#    'again',
#    'again',
#    'again',
#    'again',
#    'again',
#    'again',
#    'again',
#    'again',
#    'but',
#    'but',
#    'but',
#    'but',
#    'but',
#    'but',
#    'but',
#    'but',
#    'but',
#    'but',
#    'because',
#    'because',
#    'because',
#    'because',
#    'because',
#    'because',
#    'because',
#    'because',
#    'because',
#    'because',
#    'because',
#    'because',
#    'because',
#    'because',
#    'because',
#    'because',
#    'because',
#    'because',
#    'because',
#    'because',
#    'nice',
#    'nice',
#    'nice',
#    'nice',
#    'nice',
#    'nice',
#    'nice',
#    'nice',
#    'nice',
#    'nice']),
#  ('Geert',
#   ['yes',
#    'yes',
#    'yes',
#    'yes',
#    'yes',
#    'yes',
#    'yes',
#    'yes',
#    'yes',
#    'yes',
#    'like',
#    'like',
#    'like',
#    'like',
#    'like',
#    'like',
#    'like',
#    'like',
#    'like',
#    'like',
#    'like',
#    'like',
#    'like',
#    'like',
#    'like',
#    'like',
#    'like',
#    'like',
#    'like',
#    'like',
#    'about',
#    'about',
#    'about',
#    'about',
#    'about',
#    'about',
#    'about',
#    'about',
#    'about',
#    'about',
#    'about',
#    'about',
#    'about',
#    'about',
#    'about',
#    'about',
#    'about',
#    'about',
#    'about',
#    'about',
#    'again',
#    'again',
#    'again',
#    'again',
#    'again',
#    'but',
#    'but',
#    'but',
#    'but',
#    'but',
#    'but',
#    'but',
#    'but',
#    'but',
#    'but',
#    'but',
#    'but',
#    'but',
#    'but',
#    'but',
#    'but',
#    'but',
#    'but',
#    'but',
#    'but',
#    'but',
#    'but',
#    'but',
#    'but',
#    'but',
#    'but',
#    'but',
#    'but',
#    'but',
#    'but',
#    'because',
#    'because',
#    'nice',
#    'nice',
#    'nice',
#    'nice',
#    'nice',
#    'nice',
#    'nice',
#    'nice',
#    'nice',
#    'nice',
#    'nice',
#    'nice',
#    'nice',
#    'nice',
#    'nice',
#    'nice',
#    'nice',
#    'nice',
#    'nice',
#    'nice',
#    'nice',
#    'nice',
#    'nice',
#    'nice',
#    'nice',
#    'nice',
#    'nice',
#    'nice',
#    'nice',
#    'nice',
#    'nice',
#    'nice',
#    'nice',
#    'nice',
#    'nice',
#    'nice',
#    'nice',
#    'nice',
#    'nice',
#    'nice',
#    'nice',
#    'nice',
#    'nice',
#    'nice',
#    'nice',
#    'nice',
#    'nice',
#    'nice',
#    'nice',
#    'nice'])]

# %%
sentence_authors = []
author_per_sentence = []

for a in parsed_authors:
    sentenceList = []
    for i in range(50):
        numberWords = random.randint(5, 15)
        sentence = [random.choice(a[1]) for i in range(numberWords)]
        sentenceList.append(sentence)
        author_per_sentence.append(a[0])
    sentence_authors.append((a[0], sentenceList))

# Show 50 random sentences per author
sentence_authors
# Out:
# [('Henk-Jan',
#   [['about',
#     'about',
#     'because',
#     'but',
#     'but',
#     'yes',
#     'about',
#     'again',
#     'like',
#     'yes',
#     'like',
#     'about',
#     'yes',
#     'yes'],
#    ['again', 'because', 'about', 'yes', 'yes', 'about', 'about', 'yes', 'yes'],
#    ['yes', 'yes', 'about', 'yes', 'because', 'yes'],
#    ['about',
#     'like',
#     'yes',
#     'about',
#     'because',
#     'yes',
#     'yes',
#     'about',
#     'about',
#     'yes',
#     'like',
#     'because',
#     'about',
#     'yes'],
#    ['about',
#     'about',
#     'again',
#     'but',
#     'about',
#     'nice',
#     'yes',
#     'because',
#     'yes',
#     'nice',
#     'yes',
#     'yes',
#     'because',
#     'but'],
#    ['again', 'yes', 'yes', 'about', 'yes', 'yes', 'nice', 'about', 'because'],
#    ['about',
#     'but',
#     'about',
#     'yes',
#     'about',
#     'yes',
#     'about',
#     'about',
#     'but',
#     'about',
#     'but'],
#    ['about', 'about', 'but', 'about', 'about', 'about', 'but', 'about'],
#    ['about',
#     'because',
#     'yes',
#     'but',
#     'nice',
#     'about',
#     'yes',
#     'yes',
#     'yes',
#     'yes',
#     'again',
#     'yes',
#     'yes',
#     'again',
#     'about'],
#    ['yes', 'because', 'nice', 'about', 'again', 'because', 'yes', 'yes'],
#    ['yes', 'about', 'yes', 'again', 'like', 'because', 'but'],
#    ['yes',
#     'about',
#     'yes',
#     'but',
#     'nice',
#     'yes',
#     'about',
#     'about',
#     'about',
#     'because',
#     'but',
#     'again',
#     'about',
#     'about'],
#    ['again',
#     'because',
#     'again',
#     'yes',
#     'about',
#     'because',
#     'nice',
#     'yes',
#     'but'],
#    ['about',
#     'yes',
#     'about',
#     'because',
#     'about',
#     'about',
#     'again',
#     'about',
#     'yes',
#     'because',
#     'nice',
#     'but',
#     'but',
#     'about'],
#    ['yes',
#     'yes',
#     'yes',
#     'nice',
#     'nice',
#     'yes',
#     'again',
#     'about',
#     'but',
#     'nice',
#     'yes',
#     'yes',
#     'but',
#     'yes'],
#    ['again',
#     'nice',
#     'but',
#     'yes',
#     'about',
#     'about',
#     'about',
#     'yes',
#     'yes',
#     'yes'],
#    ['yes',
#     'but',
#     'about',
#     'about',
#     'yes',
#     'about',
#     'about',
#     'because',
#     'because',
#     'but',
#     'but',
#     'nice',
#     'because'],
#    ['because',
#     'because',
#     'about',
#     'yes',
#     'yes',
#     'about',
#     'nice',
#     'again',
#     'because',
#     'about',
#     'yes',
#     'about',
#     'yes'],
#    ['yes',
#     'about',
#     'yes',
#     'yes',
#     'nice',
#     'because',
#     'again',
#     'yes',
#     'because',
#     'because',
#     'yes',
#     'because',
#     'because'],
#    ['again',
#     'nice',
#     'yes',
#     'yes',
#     'like',
#     'nice',
#     'about',
#     'again',
#     'nice',
#     'about',
#     'like'],
#    ['yes',
#     'but',
#     'about',
#     'about',
#     'nice',
#     'yes',
#     'because',
#     'but',
#     'again',
#     'about',
#     'because',
#     'about',
#     'nice',
#     'about'],
#    ['again',
#     'again',
#     'about',
#     'about',
#     'because',
#     'about',
#     'because',
#     'because',
#     'again',
#     'about'],
#    ['again', 'because', 'about', 'again', 'because', 'yes'],
#    ['but', 'because', 'like', 'again', 'because', 'but', 'but'],
#    ['because',
#     'again',
#     'yes',
#     'about',
#     'yes',
#     'about',
#     'again',
#     'but',
#     'because',
#     'about'],
#    ['yes',
#     'about',
#     'about',
#     'about',
#     'about',
#     'again',
#     'but',
#     'but',
#     'yes',
#     'like'],
#    ['again',
#     'nice',
#     'but',
#     'again',
#     'but',
#     'but',
#     'because',
#     'because',
#     'yes',
#     'nice',
#     'about'],
#    ['yes',
#     'yes',
#     'about',
#     'about',
#     'about',
#     'because',
#     'about',
#     'yes',
#     'about',
#     'nice',
#     'because'],
#    ['like', 'yes', 'nice', 'but', 'yes', 'nice', 'about'],
#    ['yes',
#     'yes',
#     'again',
#     'yes',
#     'yes',
#     'yes',
#     'yes',
#     'about',
#     'nice',
#     'again',
#     'about',
#     'yes',
#     'about'],
#    ['again',
#     'about',
#     'because',
#     'because',
#     'nice',
#     'about',
#     'yes',
#     'yes',
#     'but',
#     'about',
#     'nice',
#     'about'],
#    ['yes',
#     'but',
#     'because',
#     'again',
#     'about',
#     'because',
#     'about',
#     'about',
#     'but',
#     'nice',
#     'yes',
#     'again',
#     'yes',
#     'because',
#     'because'],
#    ['about', 'again', 'like', 'nice', 'yes', 'about'],
#    ['yes', 'yes', 'like', 'again', 'yes', 'again'],
#    ['yes',
#     'but',
#     'yes',
#     'yes',
#     'yes',
#     'yes',
#     'about',
#     'about',
#     'about',
#     'about',
#     'yes'],
#    ['again',
#     'about',
#     'because',
#     'again',
#     'again',
#     'about',
#     'about',
#     'about',
#     'because',
#     'about',
#     'about',
#     'nice'],
#    ['like', 'about', 'because', 'about', 'about'],
#    ['yes',
#     'but',
#     'about',
#     'about',
#     'because',
#     'yes',
#     'like',
#     'about',
#     'about'],
#    ['yes',
#     'about',
#     'because',
#     'nice',
#     'yes',
#     'but',
#     'yes',
#     'nice',
#     'nice',
#     'but',
#     'about'],
#    ['about', 'about', 'yes', 'again', 'nice', 'because', 'again', 'nice'],
#    ['about',
#     'yes',
#     'nice',
#     'like',
#     'about',
#     'about',
#     'because',
#     'about',
#     'like',
#     'about',
#     'because',
#     'about',
#     'because',
#     'about'],
#    ['because',
#     'about',
#     'yes',
#     'because',
#     'yes',
#     'about',
#     'because',
#     'yes',
#     'yes',
#     'yes'],
#    ['but',
#     'nice',
#     'again',
#     'about',
#     'again',
#     'about',
#     'yes',
#     'yes',
#     'because'],
#    ['about', 'because', 'because', 'about', 'again', 'yes', 'again'],
#    ['about',
#     'about',
#     'but',
#     'again',
#     'yes',
#     'again',
#     'about',
#     'about',
#     'about',
#     'about',
#     'nice',
#     'about',
#     'yes',
#     'about',
#     'again'],
#    ['nice',
#     'because',
#     'yes',
#     'because',
#     'because',
#     'because',
#     'yes',
#     'again',
#     'yes'],
#    ['but', 'like', 'yes', 'yes', 'because', 'again', 'yes', 'about', 'nice'],
#    ['because',
#     'yes',
#     'about',
#     'yes',
#     'because',
#     'again',
#     'nice',
#     'again',
#     'nice',
#     'about',
#     'again'],
#    ['about',
#     'about',
#     'about',
#     'about',
#     'but',
#     'yes',
#     'nice',
#     'about',
#     'nice',
#     'about',
#     'again'],
#    ['yes',
#     'about',
#     'yes',
#     'about',
#     'again',
#     'nice',
#     'because',
#     'again',
#     'again']]),
#  ('Geert',
#   [['like', 'yes', 'like', 'nice', 'yes', 'yes'],
#    ['nice', 'about', 'nice', 'nice', 'about', 'nice'],
#    ['nice', 'like', 'again', 'nice', 'like', 'nice', 'about'],
#    ['yes', 'nice', 'nice', 'nice', 'like', 'but'],
#    ['like',
#     'again',
#     'nice',
#     'nice',
#     'nice',
#     'about',
#     'like',
#     'yes',
#     'nice',
#     'nice',
#     'like',
#     'nice',
#     'like',
#     'but',
#     'about'],
#    ['nice',
#     'nice',
#     'nice',
#     'about',
#     'nice',
#     'nice',
#     'nice',
#     'nice',
#     'yes',
#     'nice'],
#    ['nice', 'but', 'like', 'about', 'nice', 'nice', 'but'],
#    ['about', 'about', 'about', 'like', 'about', 'nice', 'about'],
#    ['nice',
#     'nice',
#     'nice',
#     'nice',
#     'about',
#     'but',
#     'nice',
#     'but',
#     'about',
#     'like',
#     'nice',
#     'nice'],
#    ['nice', 'like', 'again', 'nice', 'about', 'about', 'but'],
#    ['about', 'but', 'nice', 'nice', 'like', 'yes', 'like', 'about', 'nice'],
#    ['but', 'like', 'but', 'nice', 'nice', 'nice', 'but'],
#    ['again',
#     'nice',
#     'about',
#     'nice',
#     'nice',
#     'nice',
#     'about',
#     'about',
#     'nice',
#     'nice',
#     'nice',
#     'about',
#     'nice',
#     'because'],
#    ['nice', 'but', 'but', 'nice', 'like', 'yes', 'nice', 'but'],
#    ['nice',
#     'like',
#     'about',
#     'but',
#     'yes',
#     'but',
#     'like',
#     'like',
#     'nice',
#     'about',
#     'but'],
#    ['but',
#     'nice',
#     'nice',
#     'nice',
#     'but',
#     'like',
#     'but',
#     'about',
#     'yes',
#     'yes',
#     'but',
#     'like',
#     'like',
#     'about'],
#    ['about',
#     'like',
#     'about',
#     'about',
#     'nice',
#     'like',
#     'like',
#     'nice',
#     'about',
#     'nice',
#     'again',
#     'but',
#     'like',
#     'nice',
#     'nice'],
#    ['about',
#     'nice',
#     'but',
#     'about',
#     'but',
#     'nice',
#     'but',
#     'again',
#     'nice',
#     'about',
#     'nice',
#     'but',
#     'yes',
#     'nice'],
#    ['yes',
#     'nice',
#     'about',
#     'like',
#     'but',
#     'nice',
#     'nice',
#     'nice',
#     'like',
#     'nice',
#     'but',
#     'nice'],
#    ['about',
#     'nice',
#     'nice',
#     'nice',
#     'but',
#     'about',
#     'like',
#     'nice',
#     'but',
#     'nice'],
#    ['but',
#     'about',
#     'but',
#     'about',
#     'nice',
#     'like',
#     'yes',
#     'about',
#     'about',
#     'nice',
#     'about',
#     'but'],
#    ['nice',
#     'nice',
#     'again',
#     'about',
#     'nice',
#     'but',
#     'about',
#     'about',
#     'but',
#     'nice',
#     'but',
#     'about',
#     'but',
#     'nice',
#     'nice'],
#    ['but', 'about', 'about', 'about', 'yes', 'nice', 'nice', 'nice', 'but'],
#    ['nice', 'nice', 'yes', 'nice', 'nice', 'yes'],
#    ['nice', 'nice', 'nice', 'nice', 'about'],
#    ['like', 'but', 'but', 'nice', 'nice'],
#    ['but',
#     'but',
#     'yes',
#     'nice',
#     'nice',
#     'nice',
#     'but',
#     'nice',
#     'but',
#     'but',
#     'like'],
#    ['nice',
#     'like',
#     'about',
#     'nice',
#     'nice',
#     'nice',
#     'but',
#     'yes',
#     'again',
#     'nice'],
#    ['like',
#     'like',
#     'but',
#     'like',
#     'yes',
#     'but',
#     'but',
#     'but',
#     'about',
#     'nice',
#     'like',
#     'nice'],
#    ['but', 'nice', 'about', 'nice', 'nice', 'but', 'about', 'nice'],
#    ['but', 'nice', 'nice', 'nice', 'but'],
#    ['again',
#     'but',
#     'because',
#     'like',
#     'about',
#     'but',
#     'nice',
#     'but',
#     'like',
#     'like',
#     'nice'],
#    ['nice', 'about', 'like', 'nice', 'nice', 'nice'],
#    ['but',
#     'nice',
#     'but',
#     'nice',
#     'but',
#     'about',
#     'nice',
#     'but',
#     'nice',
#     'about',
#     'but',
#     'like',
#     'like',
#     'but'],
#    ['about',
#     'nice',
#     'nice',
#     'nice',
#     'like',
#     'nice',
#     'like',
#     'about',
#     'but',
#     'but',
#     'like',
#     'but',
#     'about',
#     'nice',
#     'because'],
#    ['but',
#     'nice',
#     'nice',
#     'yes',
#     'but',
#     'nice',
#     'again',
#     'about',
#     'nice',
#     'again'],
#    ['nice',
#     'but',
#     'nice',
#     'about',
#     'like',
#     'like',
#     'but',
#     'nice',
#     'but',
#     'about',
#     'nice',
#     'nice',
#     'yes'],
#    ['nice', 'nice', 'like', 'nice', 'like', 'like', 'nice', 'about', 'like'],
#    ['but',
#     'nice',
#     'nice',
#     'nice',
#     'nice',
#     'nice',
#     'again',
#     'again',
#     'yes',
#     'about',
#     'about',
#     'about'],
#    ['but',
#     'nice',
#     'nice',
#     'but',
#     'but',
#     'nice',
#     'like',
#     'but',
#     'about',
#     'about'],
#    ['about',
#     'but',
#     'nice',
#     'nice',
#     'about',
#     'but',
#     'about',
#     'again',
#     'yes',
#     'about',
#     'but',
#     'but',
#     'about',
#     'nice',
#     'but'],
#    ['nice', 'nice', 'yes', 'but', 'but'],
#    ['nice',
#     'nice',
#     'but',
#     'nice',
#     'nice',
#     'like',
#     'like',
#     'like',
#     'nice',
#     'about',
#     'nice',
#     'nice',
#     'like',
#     'nice'],
#    ['but',
#     'nice',
#     'about',
#     'again',
#     'nice',
#     'but',
#     'nice',
#     'but',
#     'but',
#     'nice'],
#    ['but', 'nice', 'yes', 'about', 'nice', 'about'],
#    ['nice',
#     'yes',
#     'nice',
#     'nice',
#     'yes',
#     'but',
#     'about',
#     'yes',
#     'about',
#     'like',
#     'nice',
#     'about',
#     'nice'],
#    ['nice', 'nice', 'like', 'nice', 'about', 'nice', 'nice'],
#    ['again', 'about', 'nice', 'because', 'like', 'again', 'about'],
#    ['but',
#     'yes',
#     'but',
#     'like',
#     'about',
#     'nice',
#     'nice',
#     'but',
#     'like',
#     'nice',
#     'nice',
#     'but'],
#    ['like',
#     'because',
#     'nice',
#     'nice',
#     'about',
#     'but',
#     'nice',
#     'again',
#     'like',
#     'nice',
#     'but',
#     'yes',
#     'nice']])]

# %%
# Insert the author's name in each sentence
# TODO: I have no idea why I would do this??
# for a in sentence_authors:
#     for ls in a[1]:
#         ls.insert(0, a[0])
        
# And combine them.
flatten_sentences = [x[1] for x in sentence_authors]
flatten_sentences = list(itertools.chain(*flatten_sentences))

flatten_sentences
# Out:
# [['again',
#   'about',
#   'about',
#   'about',
#   'about',
#   'yes',
#   'about',
#   'like',
#   'yes',
#   'about',
#   'about',
#   'but',
#   'but'],
#  ['yes', 'yes', 'nice', 'nice', 'nice'],
#  ['yes', 'because', 'yes', 'because', 'again', 'about', 'because'],
#  ['because',
#   'because',
#   'about',
#   'yes',
#   'about',
#   'because',
#   'because',
#   'because',
#   'nice',
#   'but',
#   'about',
#   'again',
#   'yes',
#   'about',
#   'yes'],
#  ['nice',
#   'again',
#   'yes',
#   'but',
#   'about',
#   'but',
#   'yes',
#   'but',
#   'about',
#   'nice'],
#  ['yes',
#   'like',
#   'about',
#   'about',
#   'about',
#   'again',
#   'about',
#   'because',
#   'but',
#   'like',
#   'again',
#   'about',
#   'about',
#   'because',
#   'about'],
#  ['nice', 'about', 'about', 'yes', 'again'],
#  ['about', 'again', 'again', 'nice', 'yes', 'about', 'like'],
#  ['nice', 'yes', 'about', 'yes', 'because'],
#  ['yes', 'because', 'about', 'like', 'but'],
#  ['about', 'about', 'but', 'yes', 'about', 'because', 'again'],
#  ['like', 'about', 'about', 'because', 'about', 'yes'],
#  ['yes',
#   'again',
#   'about',
#   'again',
#   'about',
#   'yes',
#   'again',
#   'about',
#   'but',
#   'nice',
#   'but',
#   'but',
#   'because'],
#  ['like',
#   'about',
#   'because',
#   'about',
#   'yes',
#   'yes',
#   'yes',
#   'because',
#   'because',
#   'yes'],
#  ['but',
#   'nice',
#   'nice',
#   'about',
#   'yes',
#   'about',
#   'again',
#   'about',
#   'yes',
#   'about'],
#  ['about',
#   'nice',
#   'because',
#   'nice',
#   'yes',
#   'about',
#   'yes',
#   'about',
#   'because'],
#  ['about',
#   'yes',
#   'about',
#   'because',
#   'about',
#   'but',
#   'nice',
#   'but',
#   'about',
#   'again',
#   'yes',
#   'again',
#   'again'],
#  ['yes',
#   'about',
#   'like',
#   'about',
#   'again',
#   'but',
#   'nice',
#   'like',
#   'about',
#   'yes',
#   'because'],
#  ['about',
#   'about',
#   'yes',
#   'about',
#   'because',
#   'about',
#   'yes',
#   'yes',
#   'because',
#   'yes',
#   'but',
#   'but',
#   'about'],
#  ['about', 'about', 'about', 'yes', 'but', 'about', 'yes'],
#  ['nice',
#   'because',
#   'nice',
#   'because',
#   'like',
#   'like',
#   'but',
#   'nice',
#   'about'],
#  ['about', 'nice', 'but', 'about', 'because', 'yes', 'but'],
#  ['about', 'again', 'again', 'nice', 'about', 'yes'],
#  ['because', 'because', 'about', 'about', 'but', 'yes', 'again'],
#  ['yes',
#   'yes',
#   'about',
#   'nice',
#   'but',
#   'because',
#   'yes',
#   'because',
#   'about',
#   'yes',
#   'again',
#   'about',
#   'about',
#   'about'],
#  ['about',
#   'nice',
#   'but',
#   'again',
#   'because',
#   'yes',
#   'about',
#   'about',
#   'but',
#   'about',
#   'about'],
#  ['about',
#   'yes',
#   'again',
#   'again',
#   'about',
#   'because',
#   'about',
#   'again',
#   'about',
#   'but',
#   'because',
#   'because'],
#  ['because',
#   'yes',
#   'about',
#   'but',
#   'about',
#   'about',
#   'again',
#   'yes',
#   'because',
#   'but',
#   'yes',
#   'about',
#   'about'],
#  ['because',
#   'about',
#   'about',
#   'but',
#   'about',
#   'nice',
#   'about',
#   'nice',
#   'about',
#   'about',
#   'about',
#   'about',
#   'about'],
#  ['about', 'yes', 'again', 'because', 'yes'],
#  ['yes', 'about', 'because', 'about', 'again', 'yes', 'nice'],
#  ['about',
#   'about',
#   'about',
#   'again',
#   'again',
#   'but',
#   'about',
#   'about',
#   'because',
#   'about',
#   'yes',
#   'nice',
#   'yes'],
#  ['about', 'yes', 'nice', 'but', 'again'],
#  ['about', 'yes', 'again', 'yes', 'yes', 'because', 'again', 'like'],
#  ['about', 'but', 'nice', 'about', 'because', 'because', 'yes'],
#  ['nice',
#   'because',
#   'again',
#   'again',
#   'again',
#   'nice',
#   'yes',
#   'nice',
#   'yes',
#   'about',
#   'but',
#   'about',
#   'about',
#   'again',
#   'nice'],
#  ['yes', 'again', 'again', 'because', 'about', 'nice', 'because', 'like'],
#  ['about',
#   'about',
#   'nice',
#   'because',
#   'yes',
#   'again',
#   'yes',
#   'yes',
#   'again',
#   'about',
#   'because',
#   'yes'],
#  ['yes',
#   'about',
#   'about',
#   'about',
#   'about',
#   'because',
#   'again',
#   'like',
#   'because'],
#  ['but',
#   'about',
#   'again',
#   'about',
#   'nice',
#   'yes',
#   'because',
#   'again',
#   'because',
#   'but'],
#  ['about',
#   'but',
#   'about',
#   'like',
#   'about',
#   'because',
#   'like',
#   'because',
#   'because',
#   'because',
#   'about',
#   'about',
#   'yes',
#   'but'],
#  ['like',
#   'again',
#   'about',
#   'about',
#   'yes',
#   'about',
#   'again',
#   'nice',
#   'about',
#   'yes'],
#  ['yes', 'again', 'about', 'again', 'about', 'yes', 'again'],
#  ['about', 'about', 'nice', 'about', 'but', 'yes', 'because', 'about'],
#  ['like',
#   'yes',
#   'like',
#   'but',
#   'about',
#   'because',
#   'about',
#   'yes',
#   'nice',
#   'yes',
#   'but'],
#  ['yes', 'about', 'nice', 'because', 'about', 'about', 'yes'],
#  ['yes', 'nice', 'about', 'about', 'nice', 'like', 'about', 'because'],
#  ['about', 'about', 'yes', 'yes', 'about', 'nice', 'about', 'because'],
#  ['because',
#   'yes',
#   'again',
#   'again',
#   'yes',
#   'yes',
#   'yes',
#   'about',
#   'because',
#   'about',
#   'nice',
#   'about',
#   'about'],
#  ['because', 'yes', 'about', 'nice', 'about'],
#  ['but',
#   'about',
#   'again',
#   'nice',
#   'but',
#   'again',
#   'like',
#   'nice',
#   'nice',
#   'nice',
#   'again',
#   'nice',
#   'but'],
#  ['about',
#   'nice',
#   'nice',
#   'nice',
#   'yes',
#   'like',
#   'yes',
#   'nice',
#   'about',
#   'yes',
#   'like'],
#  ['like', 'but', 'like', 'but', 'nice', 'about'],
#  ['like',
#   'but',
#   'again',
#   'like',
#   'like',
#   'nice',
#   'nice',
#   'nice',
#   'about',
#   'but',
#   'nice',
#   'yes',
#   'but'],
#  ['like',
#   'again',
#   'but',
#   'about',
#   'like',
#   'nice',
#   'but',
#   'nice',
#   'about',
#   'but',
#   'but',
#   'nice',
#   'about',
#   'nice'],
#  ['nice',
#   'nice',
#   'nice',
#   'again',
#   'nice',
#   'about',
#   'but',
#   'nice',
#   'nice',
#   'nice',
#   'but',
#   'but',
#   'like',
#   'nice',
#   'nice'],
#  ['nice',
#   'nice',
#   'but',
#   'nice',
#   'about',
#   'about',
#   'like',
#   'like',
#   'nice',
#   'but',
#   'yes',
#   'nice',
#   'nice',
#   'nice'],
#  ['nice',
#   'nice',
#   'like',
#   'nice',
#   'like',
#   'nice',
#   'but',
#   'nice',
#   'yes',
#   'but',
#   'but',
#   'like',
#   'nice'],
#  ['yes',
#   'but',
#   'again',
#   'but',
#   'like',
#   'about',
#   'because',
#   'about',
#   'like',
#   'but',
#   'about',
#   'but',
#   'like',
#   'again'],
#  ['yes',
#   'like',
#   'about',
#   'but',
#   'but',
#   'but',
#   'nice',
#   'but',
#   'because',
#   'again',
#   'yes',
#   'like'],
#  ['like',
#   'nice',
#   'yes',
#   'nice',
#   'but',
#   'nice',
#   'about',
#   'but',
#   'nice',
#   'nice',
#   'nice',
#   'nice',
#   'but',
#   'about',
#   'like'],
#  ['again', 'again', 'nice', 'nice', 'but', 'like', 'nice', 'because', 'about'],
#  ['like',
#   'about',
#   'again',
#   'because',
#   'nice',
#   'nice',
#   'nice',
#   'like',
#   'nice',
#   'like',
#   'nice',
#   'about'],
#  ['but',
#   'because',
#   'nice',
#   'nice',
#   'nice',
#   'but',
#   'but',
#   'nice',
#   'but',
#   'yes',
#   'nice',
#   'yes',
#   'but'],
#  ['yes',
#   'like',
#   'again',
#   'nice',
#   'nice',
#   'but',
#   'like',
#   'again',
#   'yes',
#   'nice',
#   'but',
#   'but',
#   'like',
#   'nice'],
#  ['nice',
#   'yes',
#   'but',
#   'again',
#   'but',
#   'but',
#   'nice',
#   'but',
#   'yes',
#   'like',
#   'nice',
#   'but'],
#  ['again',
#   'yes',
#   'nice',
#   'like',
#   'about',
#   'like',
#   'again',
#   'nice',
#   'because',
#   'like',
#   'but',
#   'nice',
#   'but',
#   'nice',
#   'nice'],
#  ['nice',
#   'about',
#   'about',
#   'but',
#   'nice',
#   'nice',
#   'but',
#   'nice',
#   'nice',
#   'nice',
#   'like',
#   'about',
#   'nice'],
#  ['like', 'about', 'but', 'but', 'yes', 'nice', 'but', 'nice', 'nice', 'yes'],
#  ['nice', 'like', 'but', 'nice', 'about', 'but', 'nice', 'like', 'about'],
#  ['nice',
#   'but',
#   'but',
#   'like',
#   'nice',
#   'nice',
#   'like',
#   'like',
#   'nice',
#   'like',
#   'about'],
#  ['nice',
#   'like',
#   'but',
#   'nice',
#   'nice',
#   'because',
#   'nice',
#   'about',
#   'nice',
#   'about',
#   'nice',
#   'about',
#   'like',
#   'nice'],
#  ['but',
#   'yes',
#   'but',
#   'about',
#   'about',
#   'nice',
#   'again',
#   'but',
#   'because',
#   'nice',
#   'but',
#   'like'],
#  ['nice',
#   'nice',
#   'yes',
#   'like',
#   'like',
#   'about',
#   'nice',
#   'but',
#   'yes',
#   'but',
#   'but',
#   'nice'],
#  ['nice', 'about', 'yes', 'yes', 'about'],
#  ['nice', 'but', 'but', 'but', 'nice', 'again', 'nice', 'yes', 'yes', 'but'],
#  ['nice',
#   'nice',
#   'nice',
#   'like',
#   'but',
#   'nice',
#   'like',
#   'nice',
#   'again',
#   'but',
#   'about',
#   'nice',
#   'nice'],
#  ['nice', 'about', 'again', 'but', 'about', 'like', 'because'],
#  ['nice', 'yes', 'nice', 'like', 'yes', 'but', 'but', 'nice', 'nice'],
#  ['nice',
#   'nice',
#   'nice',
#   'but',
#   'about',
#   'but',
#   'again',
#   'nice',
#   'like',
#   'like'],
#  ['about',
#   'like',
#   'nice',
#   'like',
#   'nice',
#   'but',
#   'nice',
#   'because',
#   'about',
#   'nice',
#   'nice',
#   'nice',
#   'nice'],
#  ['but', 'because', 'like', 'like', 'nice', 'nice', 'but'],
#  ['but', 'but', 'nice', 'about', 'yes'],
#  ['nice',
#   'but',
#   'but',
#   'but',
#   'nice',
#   'like',
#   'but',
#   'but',
#   'yes',
#   'nice',
#   'but',
#   'nice',
#   'about',
#   'but',
#   'but'],
#  ['but', 'nice', 'but', 'nice', 'nice', 'but'],
#  ['like', 'nice', 'but', 'yes', 'but', 'yes', 'nice'],
#  ['like', 'nice', 'like', 'nice', 'like', 'about', 'about'],
#  ['nice',
#   'nice',
#   'nice',
#   'because',
#   'again',
#   'nice',
#   'nice',
#   'like',
#   'nice',
#   'nice',
#   'about'],
#  ['about',
#   'again',
#   'nice',
#   'like',
#   'about',
#   'about',
#   'nice',
#   'nice',
#   'nice',
#   'yes',
#   'but',
#   'but'],
#  ['nice',
#   'about',
#   'but',
#   'nice',
#   'nice',
#   'like',
#   'but',
#   'nice',
#   'nice',
#   'but',
#   'but',
#   'like'],
#  ['like', 'but', 'about', 'but', 'nice'],
#  ['yes',
#   'like',
#   'about',
#   'about',
#   'but',
#   'but',
#   'nice',
#   'nice',
#   'nice',
#   'like',
#   'nice',
#   'nice',
#   'nice',
#   'about',
#   'yes'],
#  ['yes', 'yes', 'nice', 'but', 'nice', 'nice', 'but', 'nice', 'yes'],
#  ['nice', 'nice', 'yes', 'but', 'yes'],
#  ['like',
#   'nice',
#   'nice',
#   'like',
#   'nice',
#   'about',
#   'about',
#   'about',
#   'about',
#   'nice'],
#  ['nice', 'like', 'nice', 'but', 'but', 'about', 'nice', 'about'],
#  ['about',
#   'but',
#   'like',
#   'nice',
#   'like',
#   'about',
#   'yes',
#   'nice',
#   'but',
#   'yes',
#   'about',
#   'like'],
#  ['but',
#   'nice',
#   'nice',
#   'nice',
#   'about',
#   'like',
#   'yes',
#   'but',
#   'about',
#   'but',
#   'nice'],
#  ['but', 'about', 'about', 'about', 'about', 'but'],
#  ['nice', 'but', 'nice', 'like', 'nice', 'yes', 'like', 'but', 'nice', 'but']]

# %%
# Count the words usage per author in percentages.
percents = []

for author, sentences in sentence_authors:
    words = list(itertools.chain(*sentences))
    count = Counter(words)
    percent = {key: value/len(words) for (key, value) in count.items()}
    print('\n' + author + ':\n')
    print(percent)
    percents.append((author, percent))
# Out:
# Henk-Jan:
#
# {'about': 0.3311965811965812, 'like': 0.042735042735042736, 'again': 0.1111111111111111, 'yes': 0.19230769230769232, 'nice': 0.09615384615384616, 'because': 0.1388888888888889, 'but': 0.0876068376068376}
#
# Geert:
#
# {'about': 0.13059701492537312, 'like': 0.1455223880597015, 'again': 0.04477611940298507, 'yes': 0.08208955223880597, 'nice': 0.35447761194029853, 'because': 0.022388059701492536, 'but': 0.22014925373134328}

# %%
def determine_author(sentence, perc1, perc2):
    prod1 = prod2 = 1.0
    for word in sentence:
        prod1 *= perc1[word]
        prod2 *= perc2[word]
    return prod1 > prod2

# Test that the first 50 sentences from the first author are correctly identified
for sentence in flatten_sentences[:50]:
    determine = determine_author(sentence, percents[0][1], percents[1][1])
    print(determine, end=';')
    
print('\n')
    
# Test that the other 50 sentences are not identified as from the first author
for sentence in flatten_sentences[50:]:
    determine = determine_author(sentence, percents[0][1], percents[1][1])
    print(determine, end=';')
# Out:
# True;False;True;True;False;True;True;True;True;True;True;True;True;True;True;True;True;True;True;True;False;True;True;True;True;True;True;True;True;True;True;True;True;True;True;True;True;True;True;True;True;True;True;True;True;True;True;True;True;True;
#
# False;False;False;False;False;False;False;False;False;False;False;False;False;False;False;False;False;False;False;False;False;False;False;False;True;False;False;True;False;False;False;False;False;False;False;False;False;False;False;False;False;False;False;False;False;False;False;False;True;False;

# %%
from sklearn.cross_validation import cross_val_score, KFold
from numpy import mean
from scipy.stats import sem

def evaluate_cross_validation(clf, X, y, K):
    # create a k-fold croos validation iterator of k=5 folds
    cv = KFold(len(y), K, shuffle=True, random_state=0)
    # by default the score used is the one returned by score method of the estimator (accuracy)
    scores = cross_val_score(clf, X, y, cv=cv)
    print(scores)
    print("Mean score: {0:.3f}".format(mean(scores)))
    print("Standard error of the mean: (+/-{0:.3f})".format(sem(scores)))
    
    
# Convert to real sentences
real_sentences = [" ".join(lst[:]).strip(" ") for lst in flatten_sentences]
print(real_sentences[:2])

vec = CountVectorizer()
vec.fit_transform(real_sentences).toarray()[:5]
# Out:
# ['again about about about about yes about like yes about about but but', 'yes yes nice nice nice']
# array([[7, 1, 0, 2, 1, 0, 2],
#        [0, 0, 0, 0, 0, 3, 2],
#        [1, 1, 3, 0, 0, 0, 2],
#        [4, 1, 5, 1, 0, 1, 3],
#        [2, 1, 0, 3, 0, 2, 2]], dtype=int64)

# %%
clf = Pipeline([('vect', CountVectorizer()), ('clf', MultinomialNB())])

# just for clarity
X = real_sentences
y = author_per_sentence

evaluate_cross_validation(clf, X, y, 5)
# Out:
# [ 1.    0.95  0.9   0.85  1.  ]
# Mean score: 0.940
# Standard error of the mean: (+/-0.029)

# %%
from sklearn.cross_validation import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=33)
print(X_train[:2])
print(y_train[:2])
# Out:
# ['about about nice about but yes because about', 'yes nice about about nice like about because']
# ['Henk-Jan', 'Henk-Jan']

# %%
from sklearn import metrics

def train_and_evaluate(clf, X_train, X_test, y_train, y_test):
    
    clf.fit(X_train, y_train)
    
    print("Accuracy on training set:")
    print(clf.score(X_train, y_train))
    print("Accuracy on testing set:")
    print(clf.score(X_test, y_test))
    
    y_pred = clf.predict(X_test)
    
    print("Classification Report:")
    print(metrics.classification_report(y_test, y_pred))
    print("Confusion Matrix:")
    print(metrics.confusion_matrix(y_test, y_pred))
    
train_and_evaluate(clf, X_train, X_test, y_train, y_test)
# Out:
# Accuracy on training set:
# 0.92
# Accuracy on testing set:
# 0.96
# Classification Report:
#              precision    recall  f1-score   support
#
#       Geert       0.94      1.00      0.97        17
#    Henk-Jan       1.00      0.88      0.93         8
#
# avg / total       0.96      0.96      0.96        25
#
# Confusion Matrix:
# [[17  0]
#  [ 1  7]]

# %%
clf.predict(["yes, because I like about five to six animals."])
# Out:
# array(['Henk-Jan'],
#       dtype='<U8')

# %%
clf.predict(["No, I like two animals but that doesn't matter because they are nice."])
# Out:
# array(['Geert'],
#       dtype='<U8')

# %%
clf.predict(["The nice thing of this is, like three out of four people don't care what you say."])
# Out:
# array(['Geert'],
#       dtype='<U8')
